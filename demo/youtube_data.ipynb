# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyCP3auPVXFwgXEK7UPQEvsKbMbWJ49NoNI'
channel_id = 'UCnz-ZXXER4jOvuED5trXfEA'

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# 1. Function to get channel statistics

def get_channel_stats(youtube, channel_id):

    request = youtube.channels().list(
        part='snippet, contentDetails, statistics',
        id = channel_id)
    response = request.execute()

    data = dict(Channel_name = response['items'][0]['snippet']['title'],
                Subscribers = response['items'][0]['statistics']['subscriberCount'],
                Views = response['items'][0]['statistics']['viewCount'],
                Total_videos = response['items'][0]['statistics']['videoCount'])
    
    return data

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'Channel_name': 'techTFQ',
#  'Subscribers': '311000',
#  'Views': '17187686',
#  'Total_videos': '137'}

# %%
# Get the multiple channel ids and compare

api_key = 'AIzaSyCP3auPVXFwgXEK7UPQEvsKbMbWJ49NoNI'
channel_ids = ['UCnz-ZXXER4jOvuED5trXfEA',      # techTFQ
               'UC7cs8q-gJRlGwj4A8OmCmXg',      # Alex_The_Analyst
               'UCiT9RITQ9PW6BhXK0y2jaeg',      # Ken_Jee
               'UC2UXDak6o7rBm23k3Vv5dww',      # Tina_Huang
               'UCLLw7jmFsvfIVaUFsLs8mlQ'       # Luke_Barousse
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# Function to get all the data from group of channel's statistical data

def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    request = youtube.channels().list(
        part='snippet, contentDetails, statistics',
        id = ','.join(channel_ids))
    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][0]['snippet']['title'],
                    Subscribers = response['items'][0]['statistics']['subscriberCount'],
                    Views = response['items'][0]['statistics']['viewCount'],
                    Total_videos = response['items'][0]['statistics']['videoCount'])
        all_data.append(data)
    
    return all_data

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'Q4eAdRBxjjjRijIDr_yz4gXAei0',
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'C3-S3Z6W1ZTnqEfpwMfH_y9A9VI',
#    'id': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#    'snippet': {'title': 'Ken Jee',
# ...

# %%
# Function to get channel statistics

def get_channel_stats(youtube, channel_ids):
    
    request = youtube.channels().list(
        part='snippet, contentDetails, statistics',
        id = ','.join(channel_ids))
    response = request.execute()
    
    return response

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'NSIGspOJPj-EmVBw09zhzEuliFI',
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'WjDCibttSlRuGcBqZCJn75T3BeE',
#    'id': 'UCLLw7jmFsvfIVaUFsLs8mlQ',
#    'snippet': {'title': 'Luke Barousse',
#     'description': "What's up, Data Nerds! I'm Luke, a data analyst who is exploring how to use AI for analysis.\n\n❓ If you have a question, just drop a comment in any video. \n\n📩 Email is for business inquiries only, please.\n\n\n",
#     'customUrl': '@lukebarousse',
#     'publishedAt': '2020-08-03T09:02:41.213077Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIdro_my6YXWfudW8qM_i1Na9IWEbiIUtVgb54u0XVVmtlYQig=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AIdro_my6YXWfudW8qM_i1Na9IWEbiIUtVgb54u0XVVmtlYQig=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
# ...

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'Pm_F3s6TqfA9P4HjBpVvXZRh8wo',
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'AO6TtKRHA6tjyWJAJBJKen5k6yE',
#    'id': 'UCnz-ZXXER4jOvuED5trXfEA',
#    'snippet': {'title': 'techTFQ',
#     'description': 'Hi, I am Thoufiq! On this channel, I teach SQL, Python and Database concepts in the field of Data Analytics and Data Science in the most simplest manner possible. If this excites you then do consider subscribing.\n\nYou will also find videos covering interview questions and also videos where I provide career guidance in the field of Data Analytics and Data Science which should help you find your dream job.\n\nI aim to make techTFQ a go to YouTube channel for anyone learning SQL, Python and Databases in the field of Data Analytics and Data Science.\n\nThank you for begin here :)\n',
#     'customUrl': '@techtfq',
#     'publishedAt': '2020-06-13T05:20:37.182391Z',
# ...

# %%
# Function to get all the data from each group of channel's statistical data

def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    request = youtube.channels().list(
        part='snippet, contentDetails, statistics',
        id = ','.join(channel_ids))
    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'])
        all_data.append(data)
    
    return all_data

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# [{'Channel_name': 'Luke Barousse',
#   'Subscribers': '452000',
#   'Views': '22486509',
#   'Total_videos': '158'},
#  {'Channel_name': 'Tina Huang',
#   'Subscribers': '668000',
#   'Views': '31755821',
#   'Total_videos': '229'},
#  {'Channel_name': 'Alex The Analyst',
#   'Subscribers': '815000',
#   'Views': '36640550',
#   'Total_videos': '311'},
#  {'Channel_name': 'techTFQ',
#   'Subscribers': '311000',
#   'Views': '17187686',
#   'Total_videos': '137'},
#  {'Channel_name': 'Ken Jee',
#   'Subscribers': '260000',
#   'Views': '9047990',
#   'Total_videos': '287'}]

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
# Using pandas, to convert statical data into dataframes (rows and columns)

channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#        Channel_name Subscribers     Views Total_videos
# 0           Ken Jee      260000   9047990          287
# 1     Luke Barousse      452000  22486509          158
# 2  Alex The Analyst      815000  36640550          311
# 3        Tina Huang      668000  31755821          229
# 4           techTFQ      311000  17187686          137

# %%
channel_data.dtypes         # data types
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# dtype: object

# %%
# Type conversion ---> object(string) into int

channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])

channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# dtype: object

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
# Set plot size
sns.set(rc={'figure.figsize':(10, 8)})

# Plotting the bar plot
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %%
# Function to get all the data from each group of channel's statistical data

def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    request = youtube.channels().list(
        part='snippet, contentDetails, statistics',
        id = ','.join(channel_ids))
    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
                    
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#        Channel_name Subscribers     Views Total_videos  \
# 0        Tina Huang      668000  31755821          229
# 1  Alex The Analyst      815000  36640550          311
# 2           techTFQ      311000  17187686          137
# 3     Luke Barousse      452000  22486509          158
# 4           Ken Jee      260000   9047990          287
#
#                 playlist_id
# 0  UU2UXDak6o7rBm23k3Vv5dww
# 1  UU7cs8q-gJRlGwj4A8OmCmXg
# 2  UUnz-ZXXER4jOvuED5trXfEA
# 3  UULLw7jmFsvfIVaUFsLs8mlQ
# 4  UUiT9RITQ9PW6BhXK0y2jaeg

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Ken Jee', 'playlist_id'].iloc[0]

# %%
# 2. Function to get video ids

def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
        part = "contentDetails",
        playlistId = playlist_id)
    response = request.execute()
    
    return response

# %%
# Give maximum result taken = 50 (as per youtube api guidelines)

def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
        part = "contentDetails",
        playlistId = playlist_id,
        maxResults = 50)
    response = request.execute()

    video_ids = []
    
    # Length of the playlist_ids
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

    return len(video_ids)

# %%
get_video_ids(youtube, playlist_id)
# Out:
# 50

# %%
# get all the video ids upto maxResults = 50

def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
        part = "contentDetails",
        playlistId = playlist_id,
        maxResults = 50)
    response = request.execute()

    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                part = "contentDetails",
                playlistId = playlist_id,
                maxResults = 50,
                pageToken = next_page_token)
            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
                
            next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['QEDZaBMozIo',
#  'Hyhfa7z0jTk',
#  'L5Cis5bOwgw',
#  'M1I5HlzQges',
#  'T_-0l0ORi5I',
#  'w13zJB_jyBI',
#  'oZ9rMrqyTbI',
#  '6BrYKdqq4uA',
#  '1dAvbIMrLos',
#  'lqYxmYMkfK8',
#  '-JTU734oMfk',
#  'HVpbmu7rFYE',
#  'NQQ3DRdXAXE',
#  'xpi-M2j3NmE',
#  'X07w7QFoLpc',
#  'RRnThAtKuq0',
#  'r3zOpjEOkgE',
#  's-XYFEzy9Wc',
#  'iBh1wl4o6V4',
#  'L6lXKdP4Qbg',
#  'xGDl6rlBygU',
#  'SY6y6Y8C594',
#  '1RUj2aLQx8I',
#  'MkzZXSw1Glk',
#  '9neDFXTxKxA',
#  'UaNNVukM27g',
#  '3lN0-S3symM',
#  'M-AN8eWLxms',
#  'MXFZhbvQqM8',
#  '54n61XjKifI',
#  'pyWYIRR8rrE',
#  'onwRfbt--cw',
#  'u6P23ouSYhA',
#  'RMMVuvS7S_g',
#  '5AwbPAV8FS0',
#  'A2OQgU0IRNo',
#  'x5Q_nrIqFik',
#  '7ja2ELBVMlU',
#  'Z2MyLQa_vVw',
#  'JTlB9fwYRk0',
#  'OJDf_fTENJ4',
#  'nqCkdqhV-JY',
#  'b8t8lDL13sg',
#  't6CD1EwU5kc',
#  'eIxHe45hzhQ',
#  '3NJOWWvNK3I',
#  '4_VtMWJSo1o',
#  'OybXWl3IWvI',
#  'nRHPQ5ZeB5Y',
#  '0JWC4M0Qhqc',
#  'oNvyvYGw5n4',
#  'GaZRuchRCyw',
#  'EBjYqC3aNTA',
#  'QMP858aZcow',
#  '0ItYIoOrrUs',
# ...

# %%
len(get_video_ids(youtube, playlist_id))
# Out:
# 287

# %%
# 3. Get the video info details

def get_video_details(youtube, video_ids):

    request = youtube.videos().list(
        part = "snippet, statistics",
        id = ','.join(video_ids[:50]))

    response = request.execute()
    return response

# %%
get_video_details(youtube, video_ids)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'N_0nmKfvmqv94Zk3hiIyeGy79e0',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'VrIC7EUZp5Djc2znrLiPQ7Si4EU',
#    'id': 'QEDZaBMozIo',
#    'snippet': {'publishedAt': '2024-04-22T10:00:19Z',
#     'channelId': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#     'title': 'Moving On',
# ...

# %%
def get_video_details(youtube, video_ids):
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part = "snippet, statistics",
            id = ','.join(video_ids[i:i+50]))

        response = request.execute()
        return response

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                part = 'snippet, statistics',
                id = ','.join(video_ids[i:i+50]))
        response = request.execute()

        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Dislikes = video['statistics'].get('dislikeCount', 0),
                               Comments = video['statistics'].get('commentCount', 0)
                               )                   
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_details
# Out:
# [{'Title': 'Moving On',
#   'published_date': '2024-04-22T10:00:19Z',
#   'Views': '8918',
#   'Likes': '415',
#   'Dislikes': 0,
#   'Comments': '88'},
#  {'Title': 'How Does ChatGPT Image Analysis Do on an IQ Test?',
#   'published_date': '2023-11-30T12:00:22Z',
#   'Views': '2808',
#   'Likes': '72',
#   'Dislikes': 0,
#   'Comments': '24'},
#  {'Title': 'A Data Dream Come True',
#   'published_date': '2023-11-17T12:00:28Z',
#   'Views': '2311',
#   'Likes': '95',
#   'Dislikes': 0,
#   'Comments': '23'},
#  {'Title': 'The Death of the Full-Time Job (Rise of the Contractor)',
#   'published_date': '2023-09-22T11:46:35Z',
#   'Views': '6252',
#   'Likes': '413',
#   'Dislikes': 0,
#   'Comments': '77'},
#  {'Title': 'How to Survive a Down Data Job Market',
#   'published_date': '2023-09-05T10:50:39Z',
#   'Views': '17409',
#   'Likes': '576',
#   'Dislikes': 0,
#   'Comments': '63'},
#  {'Title': 'The Harsh Reality of the Data Job Market',
# ...

# %%
len(video_details)
# Out:
# 287

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  Title        published_date  \
# 0                                            Moving On  2024-04-22T10:00:19Z
# 1    How Does ChatGPT Image Analysis Do on an IQ Test?  2023-11-30T12:00:22Z
# 2                               A Data Dream Come True  2023-11-17T12:00:28Z
# 3    The Death of the Full-Time Job (Rise of the Co...  2023-09-22T11:46:35Z
# 4                How to Survive a Down Data Job Market  2023-09-05T10:50:39Z
# ..                                                 ...                   ...
# 282                How to Simulate NBA Games in Python  2018-11-19T23:31:49Z
# 283          Should You Get A Masters in Data Science?  2018-11-14T01:39:33Z
# 284  How I Became A Data Scientist From a Business ...  2018-11-12T00:26:08Z
# 285  Predicting Season Long NBA Wins Using Multiple...  2018-07-10T16:39:52Z
# 286  Predicting Crypto-Currency Price Using RNN lST...  2017-11-18T20:04:51Z
#
#      Views Likes  Dislikes Comments
# ...

# %%
video_data['published_date'] = pd.to_datetime(video_data['published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Dislikes'] = pd.to_numeric(video_data['Dislikes'])
video_data
# Out:
#                                                  Title published_date  Views  \
# 0                                            Moving On     2024-04-22   8918
# 1    How Does ChatGPT Image Analysis Do on an IQ Test?     2023-11-30   2808
# 2                               A Data Dream Come True     2023-11-17   2311
# 3    The Death of the Full-Time Job (Rise of the Co...     2023-09-22   6252
# 4                How to Survive a Down Data Job Market     2023-09-05  17409
# ..                                                 ...            ...    ...
# 282                How to Simulate NBA Games in Python     2018-11-19  18705
# 283          Should You Get A Masters in Data Science?     2018-11-14  20814
# 284  How I Became A Data Scientist From a Business ...     2018-11-12   6579
# 285  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   9190
# 286  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  19428
#
#      Likes  Dislikes Comments
# ...

# %%
top_reated_videos = video_data.sort_values(by='Views', ascending = False).head(10)

# %%
top_reated_videos
# Out:
#                                                  Title published_date  \
# 189  How I Would Learn Data Science (If I Had to St...     2020-05-08
# 165  Beginner Kaggle Data Science Project Walk-Thro...     2020-07-17
# 210  The Best Free Data Science Courses Nobody is T...     2020-03-09
# 69   How I Would Learn Data Science in 2022 (If I H...     2021-12-27
# 216  3 Proven Data Science Projects for Beginners (...     2020-02-17
# 202  Data Science Project from Scratch - Part 1 (Pr...     2020-04-03
# 255  The Projects You Should Do To Get A Data Scien...     2019-07-30
# 215  How to Set Up Your Data Science Environment (A...     2020-02-21
# 186  How to Make A Data Science Portfolio Website w...     2020-05-15
# 102     Why You Probably Won't Become a Data Scientist     2021-04-09
#
#        Views  Likes  Dislikes Comments
# 189  1401843  48900         0     1987
# 165   376752   8075         0      444
# 210   350444  21228         0      621
# ...

# %%
ax1 = sns.barplot(x='Views', y ='Title', data=top_reated_videos)

# %%
# Add a new month column

video_data['Month'] = pd.to_datetime(video_data['published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title published_date  Views  \
# 0                                            Moving On     2024-04-22   8918
# 1    How Does ChatGPT Image Analysis Do on an IQ Test?     2023-11-30   2808
# 2                               A Data Dream Come True     2023-11-17   2311
# 3    The Death of the Full-Time Job (Rise of the Co...     2023-09-22   6252
# 4                How to Survive a Down Data Job Market     2023-09-05  17409
# ..                                                 ...            ...    ...
# 282                How to Simulate NBA Games in Python     2018-11-19  18705
# 283          Should You Get A Masters in Data Science?     2018-11-14  20814
# 284  How I Became A Data Scientist From a Business ...     2018-11-12   6579
# 285  Predicting Season Long NBA Wins Using Multiple...     2018-07-10   9190
# 286  Predicting Crypto-Currency Price Using RNN lST...     2017-11-18  19428
#
#      Likes  Dislikes Comments Month
# ...

# %%
# Calculate total number of videos each month

videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    23
# 1    Aug    27
# 2    Dec    20
# 3    Feb    25
# 4    Jan    29
# 5    Jul    27
# 6    Jun    20
# 7    Mar    32
# 8    May    24
# 9    Nov    22
# 10   Oct    17
# 11   Sep    21

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories = sort_order, ordered = True)

# %%
videos_per_month.sort_index()
# Out:
#       Month  size
# Month
# Jan     Jan    29
# Feb     Feb    25
# Mar     Mar    32
# Apr     Apr    23
# May     May    24
# Jun     Jun    20
# Jul     Jul    27
# Aug     Aug    27
# Sep     Sep    21
# Oct     Oct    17
# Nov     Nov    22
# Dec     Dec    20

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
video_data.to_csv('video_details(techTFQ).csv')
